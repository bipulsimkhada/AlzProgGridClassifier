# %%
import sys
import os
from pathlib import Path

sys.path.append(str(Path.cwd().parents[0]))

# %load_ext autoreload
# %autoreload 2

# %%
from experiments.analysis import get_results

df_loss_s1 = get_results("../results/cv/loss", "s1")

# %%
df_loss_s1
# Out:
#               name overall_accuracy overall_balanced_accuracy  \
# 0  s1_severity_025  0.8772 ± 0.0073           0.8723 ± 0.0076
# 1  s1_severity_050  0.8758 ± 0.0083           0.8719 ± 0.0068
# 2  s1_severity_075  0.8715 ± 0.0099           0.8682 ± 0.0086
# 3  s1_severity_000  0.8671 ± 0.0140           0.8652 ± 0.0138
# 4  s1_severity_100  0.8636 ± 0.0269           0.8615 ± 0.0290
#
#    stable_accuracy stable_balanced_accuracy converter_accuracy  \
# 0  0.9155 ± 0.0059          0.9088 ± 0.0067    0.6039 ± 0.0227
# 1  0.9161 ± 0.0084          0.9100 ± 0.0068    0.5890 ± 0.0175
# 2  0.9105 ± 0.0072          0.9044 ± 0.0078    0.5935 ± 0.0291
# 3  0.9049 ± 0.0135          0.8992 ± 0.0137    0.5976 ± 0.0282
# 4  0.9015 ± 0.0268          0.8954 ± 0.0317    0.5935 ± 0.0341
#
#   converter_balanced_accuracy
# 0             0.5793 ± 0.0321
# 1             0.5674 ± 0.0456
# 2             0.5718 ± 0.0436
# 3             0.5878 ± 0.0267
# 4             0.5689 ± 0.0548
